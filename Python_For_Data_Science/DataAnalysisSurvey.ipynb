# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\flpas\OneDrive - Connection Systems Development\large_files\python_for_DA\survey_results_public.csv", index_col="ResponseId")
schema_df = pd.read_csv(r"C:\Users\flpas\OneDrive - Connection Systems Development\large_files\python_for_DA\survey_results_schema.csv", index_col="qname")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 1000)

# %%
schema_df_sorted = schema_df.sort_index()
df_filt = df.loc[:, ['Age', 'Employment', 'RemoteWork', 'Country', 'CompTotal', 'LanguageWantToWorkWith', 'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith', 'WebframeWantToWorkWith']]
# df.head()
# df.columns
df_filt
# Out:
#                            Age  \
# ResponseId
# 1              18-24 years old
# 2              25-34 years old
# 3              45-54 years old
# 4              25-34 years old
# 5              25-34 years old
# ...                        ...
# 89180          25-34 years old
# 89181          18-24 years old
# 89182        Prefer not to say
# 89183       Under 18 years old
# 89184          35-44 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
# ...                                                       ...
# 89180       Employed, full-time;Independent contractor, fr...
# ...

# %%
# lng = ['Python', 'python']
lng_prog = (df_filt['LanguageWantToWorkWith'].str.contains('Python', 'python'))
lng_prog.value_counts()
# Out:
# LanguageWantToWorkWith
# False    45994
# True     34715
# Name: count, dtype: int64
